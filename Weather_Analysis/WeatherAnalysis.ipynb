# %%
import numpy as np
import pandas as pd

# %%
path = '/content/weatherHistory.csv'
df=pd.read_csv(path)

# %%
df.sample(10)
# Out:
#                       Formatted Date        Summary Precip Type  \
# 76804  2014-11-12 08:00:00.000 +0100  Mostly Cloudy        rain
# 14820  2007-05-17 13:00:00.000 +0200  Mostly Cloudy        rain
# 38043  2010-01-12 03:00:00.000 +0100          Clear        snow
# 7062   2006-11-28 07:00:00.000 +0100          Foggy        rain
# 43337  2010-09-17 17:00:00.000 +0200       Overcast        rain
# 64350  2013-01-12 06:00:00.000 +0100          Clear        snow
# 26480  2009-04-15 08:00:00.000 +0200  Partly Cloudy        rain
# 88676  2016-08-02 23:00:00.000 +0200  Partly Cloudy        rain
# 85038  2015-05-20 10:00:00.000 +0200  Mostly Cloudy        rain
# 77606  2014-10-15 18:00:00.000 +0200       Overcast        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 76804         9.861111                  7.088889      0.84            21.3647
# 14820        20.022222                 20.022222      0.40             5.1520
# 38043        -2.333333                 -4.966667      0.88             6.6654
# 7062          1.111111                  1.111111      1.00             4.1216
# 43337        18.983333                 18.983333      0.92             2.3506
# 64350        -4.905556                 -8.438889      0.84             7.8729
# 26480        10.750000                 10.750000      0.79            11.0768
# 88676        18.372222                 18.372222      0.90             6.2307
# 85038        22.383333                 22.383333      0.67            17.4041
# 77606        15.072222                 15.072222      0.99             5.1198
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 76804                   139.0          11.8979         0.0
# 14820                   282.0          11.2056         0.0
# 38043                   300.0           9.7566         0.0
# 7062                    356.0           0.1610         0.0
# 43337                   244.0          11.3183         0.0
# 64350                   261.0           9.9820         0.0
# 26480                   273.0           9.6117         0.0
# 88676                   295.0          15.1823         0.0
# 85038                   151.0          16.1000         0.0
# 77606                   191.0           9.9820         0.0
#
#        Pressure (millibars)                           Daily Summary
# 76804               1013.48       Mostly cloudy throughout the day.
# 14820               1009.20       Mostly cloudy throughout the day.
# 38043               1018.09  Mostly cloudy starting in the morning.
# 7062                1029.01               Foggy throughout the day.
# 43337               1013.06            Overcast throughout the day.
# 64350               1018.02  Partly cloudy starting in the morning.
# 26480               1013.02            Partly cloudy until evening.
# 88676               1016.35       Mostly cloudy throughout the day.
# 85038               1009.76       Mostly cloudy throughout the day.
# 77606               1009.67       Mostly cloudy throughout the day.

# %%
df.shape
# Out:
# (96453, 12)

# %%
df['Formatted Date'] = pd.to_datetime(df['Formatted Date'], utc=True)
df['Formatted Date']
# Out:
# 0       2006-03-31 22:00:00+00:00
# 1       2006-03-31 23:00:00+00:00
# 2       2006-04-01 00:00:00+00:00
# 3       2006-04-01 01:00:00+00:00
# 4       2006-04-01 02:00:00+00:00
#                    ...
# 96448   2016-09-09 17:00:00+00:00
# 96449   2016-09-09 18:00:00+00:00
# 96450   2016-09-09 19:00:00+00:00
# 96451   2016-09-09 20:00:00+00:00
# 96452   2016-09-09 21:00:00+00:00
# Name: Formatted Date, Length: 96453, dtype: datetime64[ns, UTC]

# %%
df.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# 25%             5.828200              116.000000         8.339800         0.0
# 50%             9.965900              180.000000        10.046400         0.0
# 75%            14.135800              290.000000        14.812000         0.0
# max            63.852600              359.000000        16.100000         0.0
#
#        Pressure (millibars)
# count          96453.000000
# mean            1003.235956
# std              116.969906
# min                0.000000
# 25%             1011.900000
# 50%             1016.450000
# 75%             1021.090000
# max             1046.380000

# %%
df = df.set_index("Formatted Date")
df.head(10)
# Out:
#                                  Summary Precip Type  Temperature (C)  \
# Formatted Date
# 2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
# 2006-04-01 03:00:00+00:00  Partly Cloudy        rain         9.222222
# 2006-04-01 04:00:00+00:00  Partly Cloudy        rain         7.733333
# 2006-04-01 05:00:00+00:00  Partly Cloudy        rain         8.772222
# 2006-04-01 06:00:00+00:00  Partly Cloudy        rain        10.822222
# 2006-04-01 07:00:00+00:00  Partly Cloudy        rain        13.772222
#
#                            Apparent Temperature (C)  Humidity  \
# Formatted Date
# 2006-03-31 22:00:00+00:00                  7.388889      0.89
# 2006-03-31 23:00:00+00:00                  7.227778      0.86
# 2006-04-01 00:00:00+00:00                  9.377778      0.89
# 2006-04-01 01:00:00+00:00                  5.944444      0.83
# 2006-04-01 02:00:00+00:00                  6.977778      0.83
# 2006-04-01 03:00:00+00:00                  7.111111      0.85
# 2006-04-01 04:00:00+00:00                  5.522222      0.95
# 2006-04-01 05:00:00+00:00                  6.527778      0.89
# 2006-04-01 06:00:00+00:00                 10.822222      0.82
# 2006-04-01 07:00:00+00:00                 13.772222      0.72
#
#                            Wind Speed (km/h)  Wind Bearing (degrees)  \
# Formatted Date
# 2006-03-31 22:00:00+00:00            14.1197                   251.0
# 2006-03-31 23:00:00+00:00            14.2646                   259.0
# 2006-04-01 00:00:00+00:00             3.9284                   204.0
# 2006-04-01 01:00:00+00:00            14.1036                   269.0
# 2006-04-01 02:00:00+00:00            11.0446                   259.0
# 2006-04-01 03:00:00+00:00            13.9587                   258.0
# 2006-04-01 04:00:00+00:00            12.3648                   259.0
# 2006-04-01 05:00:00+00:00            14.1519                   260.0
# 2006-04-01 06:00:00+00:00            11.3183                   259.0
# 2006-04-01 07:00:00+00:00            12.5258                   279.0
#
#                            Visibility (km)  Loud Cover  Pressure (millibars)  \
# Formatted Date
# 2006-03-31 22:00:00+00:00          15.8263         0.0               1015.13
# 2006-03-31 23:00:00+00:00          15.8263         0.0               1015.63
# 2006-04-01 00:00:00+00:00          14.9569         0.0               1015.94
# 2006-04-01 01:00:00+00:00          15.8263         0.0               1016.41
# 2006-04-01 02:00:00+00:00          15.8263         0.0               1016.51
# 2006-04-01 03:00:00+00:00          14.9569         0.0               1016.66
# 2006-04-01 04:00:00+00:00           9.9820         0.0               1016.72
# 2006-04-01 05:00:00+00:00           9.9820         0.0               1016.84
# 2006-04-01 06:00:00+00:00           9.9820         0.0               1017.37
# 2006-04-01 07:00:00+00:00           9.9820         0.0               1017.22
#
#                                                Daily Summary
# Formatted Date
# 2006-03-31 22:00:00+00:00  Partly cloudy throughout the day.
# 2006-03-31 23:00:00+00:00  Partly cloudy throughout the day.
# 2006-04-01 00:00:00+00:00  Partly cloudy throughout the day.
# 2006-04-01 01:00:00+00:00  Partly cloudy throughout the day.
# 2006-04-01 02:00:00+00:00  Partly cloudy throughout the day.
# 2006-04-01 03:00:00+00:00  Partly cloudy throughout the day.
# 2006-04-01 04:00:00+00:00  Partly cloudy throughout the day.
# 2006-04-01 05:00:00+00:00  Partly cloudy throughout the day.
# 2006-04-01 06:00:00+00:00  Partly cloudy throughout the day.
# 2006-04-01 07:00:00+00:00  Partly cloudy throughout the day.

# %%
data_columns = ['Apparent Temperature (C)', 'Humidity']
df_monthly_mean = df[data_columns].resample('MS').mean()
df_monthly_mean.head()
# Out:
#                            Apparent Temperature (C)  Humidity
# Formatted Date
# 2005-12-01 00:00:00+00:00                 -4.050000  0.890000
# 2006-01-01 00:00:00+00:00                 -4.173708  0.834610
# 2006-02-01 00:00:00+00:00                 -2.990716  0.843467
# 2006-03-01 00:00:00+00:00                  1.969780  0.778737
# 2006-04-01 00:00:00+00:00                 12.098827  0.728625

# %%
import seaborn as sns
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.figure(figsize=(14,6))
plt.title("Variation in Apparent Temperature and Humidity with time")
sns.lineplot(data=df_monthly_mean)
# Out:
# <Axes: title={'center': 'Variation in Apparent Temperature and Humidity with time'}, xlabel='Formatted Date'>

# %%
df1 = df_monthly_mean[df_monthly_mean.index.month==4]
print(df1)
df1.dtypes
# Out:
#                            Apparent Temperature (C)  Humidity
# Formatted Date
# 2006-04-01 00:00:00+00:00                 12.098827  0.728625
# 2007-04-01 00:00:00+00:00                 11.894421  0.536361
# 2008-04-01 00:00:00+00:00                 11.183688  0.693194
# 2009-04-01 00:00:00+00:00                 14.267076  0.567847
# 2010-04-01 00:00:00+00:00                 11.639406  0.706875
# 2011-04-01 00:00:00+00:00                 12.978997  0.591625
# 2012-04-01 00:00:00+00:00                 11.782770  0.650222
# 2013-04-01 00:00:00+00:00                 12.045563  0.677667
# 2014-04-01 00:00:00+00:00                 12.486181  0.691403
# 2015-04-01 00:00:00+00:00                 10.632801  0.547764
# 2016-04-01 00:00:00+00:00                 12.731427  0.659972
# Apparent Temperature (C)    float64
# Humidity                    float64
# dtype: object

# %%
import matplotlib.dates as mdates
fig, ax = plt.subplots(figsize=(18,7))
ax.plot(df1.loc['2006-04-01':'2016-04-01', 'Apparent Temperature (C)'], marker='o', linestyle='-',label='Apparent Temperature (C)')
ax.plot(df1.loc['2006-04-01':'2016-04-01', 'Humidity'], marker='o', linestyle='-',label='Humidity')
#ax.set_xticks(['04-01-2006','04-01-2007','04-01-2008','04-01-2009','04-01-2010','04-01-2011','04-01-2012','04-01-2013','04-01-2014','04-01-2015','04-01-2016'])
ax.xaxis.set_major_formatter(mdates.DateFormatter('%d %m %Y'))
ax.legend(loc ='center right')
ax.set_xlabel('Month of April')
# Out:
# Text(0.5, 0, 'Month of April')

# %%
sns.lmplot(x='Apparent Temperature (C)',y='Humidity',data=df_monthly_mean)
plt.show()

# %%
corr = df_monthly_mean.corr()
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
sns.distplot(df.Humidity,color='yellow')
# Out:
# <Axes: xlabel='Humidity', ylabel='Density'>

# %%
sns.relplot(data=df,x="Apparent Temperature (C)",y="Humidity",color="red",hue="Summary")

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Save the model
model.save('Weather_Analysis.h5')
